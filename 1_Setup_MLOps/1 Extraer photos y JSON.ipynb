# %% [markdown]
# **Función:** extrae fotos y fichero json del archivo Zip proporcionado
#
# **Requiere:**
# - ../datasets/imagenes_negocios.zip
#
# **Crea:**
# - ../datasets/______.jpg (ficheros de fotos)
# - ../datasets/business.json (id y labels de las fotos)

# %%
import os
import time
import json
from time import sleep
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
ejecutadoEnGoogleDrive = False # True si se ejecuta en Google Drive

# %%
if ejecutadoEnGoogleDrive:
    from google.colab import drive
    drive.mount('/content/drive')
    PATH = '/content/drive/clasificacion_imagenes'
else:
    PATH = '../'
# Out:
# Mounted at /content/drive

# %%
# %%time
ruta = PATH + "/datasets/imagenes_negocios.zip"
# Nota -- Tarda aprox 2 - 3 minutos en descomprimir
# !unzip {PATH}
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: imagenes_negocios/zR7cQ5vbBfbhFDeeRF1xGA.jpg
#   inflating: imagenes_negocios/zr7E1J9b8HD1gxgbJ3TIQQ.jpg
#   inflating: imagenes_negocios/ZR82ztyRpeJ2fIsB2nrIBw.jpg
#   inflating: imagenes_negocios/Zr8qD0XvdgKV3Es-W2AdBg.jpg
#   inflating: imagenes_negocios/ZR9T6khwqWNx0xqZgoTLXw.jpg
#   inflating: imagenes_negocios/ZrA3QZ2Cd1nYsHJSt5UjUQ.jpg
#   inflating: imagenes_negocios/zrADJQbbIJqCu0HxxLiHyg.jpg
#   inflating: imagenes_negocios/zRAHBjj2U9zpfU_JEQYWpA.jpg
#   inflating: imagenes_negocios/zRAnqSQ-dT3ClMRhOIU8kw.jpg
#   inflating: imagenes_negocios/zRaont_U0smfDXsm5x1VMg.jpg
#   inflating: imagenes_negocios/Zraq0-7BF0ugtQYt7S7dag.jpg
#   inflating: imagenes_negocios/zra_aUfT4IlLkxMlOS9W_g.jpg
#   inflating: imagenes_negocios/zrb26vbyOlbSnozX5aLHFQ.jpg
#   inflating: imagenes_negocios/ZrB3tkl1PLcKkdnK2ZoUSg.jpg
#   inflating: imagenes_negocios/zRBTcPDcBfRipkoYoUayGA.jpg
# ...
